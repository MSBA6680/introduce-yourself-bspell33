# %% [markdown]
# My name is Bryson. I am a student in the MSBA6680 program. I am excited to be part of this class and looking forward to learning more about Financial Analytics. Outside of school, I enjoy fishing. I look forward to getting to know everyone this semester!
